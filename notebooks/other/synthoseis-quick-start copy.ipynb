# %% [markdown]
# ## Synthoseis Quick Start Notebook

# %% [markdown]
# Synthoseis is an open source, Python-based tool used for generating pseudo-random seismic data. The goal of Synthoseis is to generate realistic seismic data for deep learning training. This notebook will serve as a guide to getting your first Synthoseis model up and running. Future notebooks will discuss seismic outputs, visualizations, and building a custom rock properties model.

# %% [markdown]
# ### Environment Build
#
# To install the necessary packages, use the `environment.yml` file to create a virtual or conda environment. Please note that the most recent version of Synthoseis has been refactored to work with Python 3.10.

# %% [markdown]
# ### Imports

# %% [markdown]
# Within the main directory of the repo is a script called `main.py`. This is the primary script to run the program. Import `main.py`, along with visualization tools to view the results.

# %%
import main as mn 
import numpy as np
import json
import pprint as pp
import matplotlib.pyplot as plt
# Out:
# /raid/ridhwan/.venv/lib/python3.10/site-packages/bruges/__init__.py:20: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %% [markdown]
# ### Building your first model

# %% [markdown]
# The config json file is the method for defining some of the key aspects of your seismic survey including survey size, seismic bandwith, column height range, number of faults, sand thickness ranges, and the presence of geobodies like salt and channels. Please note that setting `include_channels: True` will signifcantly increase compute time and memory consumption. Below is an example config file that can be found in `./config/example.json`.

# %%
rock_model = json.load(open('./config/example.json', 'r'))
pp.pprint(rock_model)
# Out:
# {'bandwidth_high': [60.0, 65.0],
#  'bandwidth_low': [10.0, 15.0],
#  'bandwidth_ord': 4,
#  'basin_floor_fans': False,
#  'broadband_qc_volume': False,
#  'closure_types': ['simple', 'faulted'],
#  'cube_shape': [300, 300, 1250],
#  'digi': 4,
#  'dip_factor_max': 1,
#  'extra_qc_plots': True,
#  'incident_angles': [0],
#  'include_channels': False,
#  'include_salt': True,
#  'infill_factor': 10,
#  'initial_layer_stdev': [5.0, 10.0],
#  'max_column_height': [150.0, 150.0],
#  'max_number_faults': 6,
#  'min_closure_voxels_faulted': 2500,
#  'min_closure_voxels_onlap': 500,
#  'min_closure_voxels_simple': 500,
#  'min_number_faults': 1,
#  'model_qc_volumes': False,
#  'multiprocess_bp': True,
#  'pad_samples': 10,
#  'partial_voxels': True,
#  'project': 'example',
#  'project_folder': '/raid/ridhwan/synthoseis/synthoseis_example',
#  'sand_layer_fraction': {'max': 0.25, 'min': 0.05},
#  'sand_layer_thickness': 2,
#  'seabed_min_depth': [20, 50],
#  'signal_to_noise_ratio_db': [20.5, 30.5, 35.5],
#  'thickness_max': 25,
#  'thickness_min': 8,
#  'variable_shale_ng': False,
#  'verbose': True,
#  'work_folder': '/raid/ridhwan/synthoseis',
#  'write_to_hdf': False}

# %% [markdown]
# ### Running the model

# %% [markdown]
# Once you've defined the parameters of your seismic data, call the `build_model()` function in `main.py`. This will take the config `.json` file as an input, as well as a `run_id` defined by the user. Users also have the option to use `test_mode`. Test mode can take an integer as an input and returns a smaller seismic volume than defined in the config file. This is great for testing prior to running the full size model.

# %%
mn.build_model(user_json='./config/example.json', run_id=20)
# Out:
# Coherent smiles will be inserted
# Salt will be inserted. noise_stretch_factor = 1.26
#
# Model folder: /raid/ridhwan/synthoseis/synthoseis_example/seismic__2025.59608329_20
# Creating directory: /raid/ridhwan/synthoseis/synthoseis_example/seismic__2025.59608329_20
# Creating directory: /raid/ridhwan/synthoseis/temp_folder__2025.59608329_20
#
# Keyfile created at /raid/ridhwan/synthoseis/synthoseis_example/seismic__2025.59608329_20/seismicCube_2025.59608329.key
# self.cfg.num_lyr_lut =  25000
# onlap_layer_list =  [ 31  64  83 167]
# Number of onlapping flags: 4
#  ... horizon number for first onlap episode = 31
#  ... number of channelFlags: 0
#  ... horizon number for first channel episode: 0
# 	Indices for shallowest point in cube: 299, 0
# Building random depth map at base of model
# azi, dip, dipping_plane min/mean/max = 36.85434390345399, 0.0017084456741923715, 0.00, 0.01, 0.02
# current_depth_map min/mean/max = 12463.58, 12850.11, 13239.32
# thickness_map min/mean/max = 2.12, 34.56, 69.96
# Layer 0, depth_maps.shape = (300, 300)
# Building Layer 1
#  1.0, 0.4021322970112322,  1.5565669272389715,  0.2604012582512528
# azi, dip, dipping_plane min/mean/max = 282.2242890697492, 0.019239490975510365, 0.00, 0.08, 0.17
# current_depth_map min/mean/max = 12441.00, 12806.60, 13215.19
# thickness_map min/mean/max = 17.82, 43.51, 68.24
# Layer 1, depth_maps.shape = (300, 300, 2)
# Building Layer 2
#  1.0, 0.6954132001098439,  1.252606250553789,  0.13203979826171577
# azi, dip, dipping_plane min/mean/max = 114.39274150859102, 0.19488629565836102, 0.00, 0.95, 1.90
# current_depth_map min/mean/max = 12384.45, 12765.33, 13182.04
# thickness_map min/mean/max = 31.12, 41.27, 56.54
# Layer 2, depth_maps.shape = (300, 300, 3)
# Building Layer 3
#  1.0, 0.6523824398850139,  1.3689994074009866,  0.17252032919535856
# azi, dip, dipping_plane min/mean/max = 358.21133994540935, 0.01792241169833786, 0.00, 0.07, 0.14
# current_depth_map min/mean/max = 12300.78, 12685.69, 13096.93
# thickness_map min/mean/max = 52.20, 79.64, 109.36
# Layer 3, depth_maps.shape = (300, 300, 4)
# Building Layer 4
#  1.0000000000000002, 0.7524375604802179,  1.314491799467444,  0.10429709001689733
# azi, dip, dipping_plane min/mean/max = 73.84804436201804, 0.16469108267497856, 0.00, 0.75, 1.51
# current_depth_map min/mean/max = 12260.22, 12649.22, 13063.19
# thickness_map min/mean/max = 22.95, 36.47, 52.48
# Layer 4, depth_maps.shape = (300, 300, 5)
# Building Layer 5
#  1.0, 0.3777485059577468,  1.8181219328733103,  0.2716889008757079
# azi, dip, dipping_plane min/mean/max = 191.0263695690626, 0.028290403267276498, 0.00, 0.12, 0.24
# current_depth_map min/mean/max = 12234.74, 12625.43, 13039.68
# thickness_map min/mean/max = 8.98, 23.79, 44.96
# Layer 5, depth_maps.shape = (300, 300, 6)
# Building Layer 6
#  1.0, 0.45483100977102076,  1.5408174255849802,  0.28289448588036686
# azi, dip, dipping_plane min/mean/max = 315.5319093113058, 0.021799431191960927, 0.00, 0.11, 0.23
# current_depth_map min/mean/max = 12194.60, 12590.52, 13002.67
# thickness_map min/mean/max = 16.17, 34.91, 52.97
# Layer 6, depth_maps.shape = (300, 300, 7)
# Building Layer 7
#  0.9999999999999999, 0.3074778540307165,  1.5422766484211683,  0.30085554081988675
# azi, dip, dipping_plane min/mean/max = 48.440586286019446, 0.06980525012545669, 0.00, 0.36, 0.73
# current_depth_map min/mean/max = 12134.24, 12519.73, 12941.19
# thickness_map min/mean/max = 21.63, 70.80, 110.06
# Layer 7, depth_maps.shape = (300, 300, 8)
# Building Layer 8
#  1.0, 0.4369074516949252,  1.5679462919027407,  0.3197341910316955
# azi, dip, dipping_plane min/mean/max = 5.2115243421989454, 0.02120426794460717, 0.00, 0.09, 0.17
# current_depth_map min/mean/max = 12094.95, 12478.80, 12903.48
# thickness_map min/mean/max = 17.76, 40.92, 65.05
# Layer 8, depth_maps.shape = (300, 300, 9)
# Building Layer 9
#  1.0, 0.3399379031856441,  1.8971404991390484,  0.36445650454823875
# azi, dip, dipping_plane min/mean/max = 300.67623175978946, 0.027958532755546606, 0.00, 0.14, 0.28
# current_depth_map min/mean/max = 12024.60, 12423.75, 12830.24
# thickness_map min/mean/max = 18.54, 55.05, 104.89
# Layer 9, depth_maps.shape = (300, 300, 10)
# Building Layer 10
#  1.0, 0.31514936457057985,  1.4777323425313564,  0.27240838522736294
# azi, dip, dipping_plane min/mean/max = 293.02500311736463, 0.004149636323071193, 0.00, 0.02, 0.04
# current_depth_map min/mean/max = 11963.83, 12328.63, 12765.63
# thickness_map min/mean/max = 29.94, 95.13, 140.49
# Layer 10, depth_maps.shape = (300, 300, 11)
# Building Layer 11
#  1.0, 0.4477228142118579,  1.6935725191728301,  0.30797707156183546
# azi, dip, dipping_plane min/mean/max = 103.24839680311827, 0.019380921032161713, 0.00, 0.09, 0.17
# current_depth_map min/mean/max = 11932.33, 12286.89, 12740.09
# thickness_map min/mean/max = 18.98, 41.74, 70.17
# Layer 11, depth_maps.shape = (300, 300, 12)
# Building Layer 12
#  1.0, 0.5722800869157698,  1.3880262180256953,  0.1819749935565208
# azi, dip, dipping_plane min/mean/max = 283.83410917641794, 0.10922748492337175, 0.00, 0.49, 0.98
# current_depth_map min/mean/max = 11872.81, 12230.59, 12667.38
# thickness_map min/mean/max = 34.06, 56.30, 74.91
# Layer 12, depth_maps.shape = (300, 300, 13)
# Building Layer 13
#  1.0000000000000002, 0.6689275542844608,  1.307106983064754,  0.13663402873216315
# azi, dip, dipping_plane min/mean/max = 71.66898313746337, 0.01427710867421117, 0.00, 0.07, 0.13
# current_depth_map min/mean/max = 11798.54, 12119.89, 12590.93
# thickness_map min/mean/max = 74.27, 110.70, 144.57
# Layer 13, depth_maps.shape = (300, 300, 14)
# Building Layer 14
#  1.0000000000000002, 0.4687130648122,  1.6571415093387392,  0.29684839963504694
# azi, dip, dipping_plane min/mean/max = 322.6228634978443, 0.08022431478767555, 0.00, 0.41, 0.83
# current_depth_map min/mean/max = 11762.19, 12066.41, 12548.10
# thickness_map min/mean/max = 24.75, 53.48, 91.48
# Layer 14, depth_maps.shape = (300, 300, 15)
# Building Layer 15
#  1.0, 0.4261049125265465,  1.7670016999064462,  0.29680034703652597
# azi, dip, dipping_plane min/mean/max = 280.3108735161756, 0.15315240115785633, 0.00, 0.66, 1.31
# current_depth_map min/mean/max = 11705.24, 11994.42, 12485.05
# thickness_map min/mean/max = 33.30, 71.99, 124.81
# Layer 15, depth_maps.shape = (300, 300, 16)
# Building Layer 16
#  1.0, 0.3326290534680578,  1.5635908015822486,  0.23229900361601047
# azi, dip, dipping_plane min/mean/max = 252.86622400448658, 0.016414390861175465, 0.00, 0.08, 0.15
# current_depth_map min/mean/max = 11646.15, 11915.14, 12431.06
# thickness_map min/mean/max = 26.36, 79.29, 124.56
# Layer 16, depth_maps.shape = (300, 300, 17)
# Building Layer 17
#  0.9999999999999999, 0.30566552813680636,  1.8298357081839862,  0.40349283934619606
# azi, dip, dipping_plane min/mean/max = 70.35270858311944, 0.012190580863224998, 0.00, 0.06, 0.11
# current_depth_map min/mean/max = 11603.44, 11876.68, 12388.77
# thickness_map min/mean/max = 11.87, 38.45, 69.77
# Layer 17, depth_maps.shape = (300, 300, 18)
# Building Layer 18
#  1.0, 0.28470574485917,  1.7946524080548398,  0.3586550293433669
# azi, dip, dipping_plane min/mean/max = 50.71993591776322, 0.2366552269349379, 0.00, 1.23, 2.46
# current_depth_map min/mean/max = 11550.02, 11843.73, 12349.75
# thickness_map min/mean/max = 7.54, 32.95, 66.37
# Layer 18, depth_maps.shape = (300, 300, 19)
# Building Layer 19
#  0.9999999999999999, 0.33260206805633785,  1.6222681691011571,  0.3171184108533058
# azi, dip, dipping_plane min/mean/max = 14.834312040391984, 0.2514728412007181, 0.00, 1.13, 2.27
# current_depth_map min/mean/max = 11538.11, 11819.33, 12329.36
# thickness_map min/mean/max = 4.64, 24.40, 40.35
# Layer 19, depth_maps.shape = (300, 300, 20)
# Building Layer 20
#  1.0, 0.6175908393648606,  1.4606655794044183,  0.13321372679262627
# azi, dip, dipping_plane min/mean/max = 177.19093538609908, 0.14515992879152606, 0.00, 0.56, 1.12
# current_depth_map min/mean/max = 11457.34, 11757.75, 12270.02
# thickness_map min/mean/max = 34.65, 61.59, 88.28
# Layer 20, depth_maps.shape = (300, 300, 21)
# Building Layer 21
#  1.0, 0.3002494737488053,  1.9999612294989495,  0.35824494997350187
# azi, dip, dipping_plane min/mean/max = 72.00966825553779, 0.09689416084435298, 0.00, 0.45, 0.90
# current_depth_map min/mean/max = 11365.68, 11685.12, 12189.72
# thickness_map min/mean/max = 22.79, 72.63, 139.85
# Layer 21, depth_maps.shape = (300, 300, 22)
# Building Layer 22
#  1.0, 0.6233563913088609,  1.2489596937024317,  0.14452868584459902
# azi, dip, dipping_plane min/mean/max = 303.4550626451529, 0.08919139334770299, 0.00, 0.46, 0.91
# current_depth_map min/mean/max = 11338.18, 11641.75, 12154.33
# thickness_map min/mean/max = 25.92, 43.37, 55.62
# Layer 22, depth_maps.shape = (300, 300, 23)
# Building Layer 23
#  1.0, 0.3495320702766289,  2.0130726311405325,  0.36508429317651775
# azi, dip, dipping_plane min/mean/max = 341.59494450901985, 0.13310206783237133, 0.00, 0.62, 1.24
# current_depth_map min/mean/max = 11287.44, 11598.27, 12080.22
# thickness_map min/mean/max = 14.07, 43.48, 88.15
# Layer 23, depth_maps.shape = (300, 300, 24)
# Building Layer 24
#  1.0, 0.6427282265350406,  1.4879623569475375,  0.2015802499815493
# azi, dip, dipping_plane min/mean/max = 29.41644575095721, 0.031298476711142165, 0.00, 0.16, 0.31
# current_depth_map min/mean/max = 11232.61, 11549.11, 12025.25
# thickness_map min/mean/max = 31.53, 49.16, 73.04
# Layer 24, depth_maps.shape = (300, 300, 25)
# Building Layer 25
#  1.0000000000000002, 0.17595345280064423,  1.9619412199592305,  0.45469880816201996
# azi, dip, dipping_plane min/mean/max = 223.66501588674424, 0.05952515289164795, 0.00, 0.31, 0.62
# current_depth_map min/mean/max = 11170.31, 11502.60, 11963.14
# thickness_map min/mean/max = 8.52, 46.51, 88.40
# Layer 25, depth_maps.shape = (300, 300, 26)
# Building Layer 26
#  1.0, 0.45912244012092174,  1.4426299774268683,  0.25542839179945825
# azi, dip, dipping_plane min/mean/max = 140.14660271654185, 0.004689894907104475, 0.00, 0.02, 0.05
# current_depth_map min/mean/max = 11095.79, 11429.23, 11882.24
# thickness_map min/mean/max = 33.76, 73.37, 105.89
# Layer 26, depth_maps.shape = (300, 300, 27)
# Building Layer 27
#  1.0000000000000002, 0.2869466930157727,  1.6761186154208858,  0.3988523993934666
# azi, dip, dipping_plane min/mean/max = 29.92409726127083, 0.12848742273639502, 0.00, 0.65, 1.29
# current_depth_map min/mean/max = 11062.14, 11387.01, 11838.87
# thickness_map min/mean/max = 12.21, 42.22, 72.70
# Layer 27, depth_maps.shape = (300, 300, 28)
# Building Layer 28
#  1.0, 0.16747238243248996,  1.8489828702362736,  0.3961372684868169
# azi, dip, dipping_plane min/mean/max = 239.18717005383098, 0.02619965703006011, 0.00, 0.13, 0.27
# current_depth_map min/mean/max = 11014.20, 11349.68, 11790.07
# thickness_map min/mean/max = 6.31, 37.33, 70.43
# Layer 28, depth_maps.shape = (300, 300, 29)
# Building Layer 29
#  1.0, 0.5018699435828101,  1.6859900461353394,  0.24063274074229307
# azi, dip, dipping_plane min/mean/max = 262.49702330253706, 0.00801524115094987, 0.00, 0.03, 0.07
# current_depth_map min/mean/max = 10966.16, 11302.66, 11755.65
# thickness_map min/mean/max = 23.50, 47.02, 79.21
# Layer 29, depth_maps.shape = (300, 300, 30)
# Building Layer 30
#  1.0, 0.6633126735660125,  1.3502610443859047,  0.17088815423339987
# azi, dip, dipping_plane min/mean/max = 9.733030506552897, 0.1350032331537111, 0.00, 0.58, 1.15
# current_depth_map min/mean/max = 10942.56, 11276.50, 11725.80
# thickness_map min/mean/max = 19.99, 26.16, 35.40
# Layer 30, depth_maps.shape = (300, 300, 31)
# Building Layer 31
#  1.0000000000000002, 0.40378108217303177,  1.462809461212514,  0.2873317091154422
# azi, dip, dipping_plane min/mean/max = 31.561223953736683, 0.046386140794842934, 0.00, 0.24, 0.47
# current_depth_map min/mean/max = 10898.93, 11231.05, 11680.49
# thickness_map min/mean/max = 18.99, 45.46, 65.28
# Layer 31, depth_maps.shape = (300, 300, 32)
# Building Layer 32
#  1.0000000000000002, 0.2098905944531334,  1.8620834196101157,  0.4218167956562062
# azi, dip, dipping_plane min/mean/max = 174.59890421903108, 0.06624696509128802, 0.00, 0.27, 0.53
# current_depth_map min/mean/max = 10811.60, 11131.16, 11596.38
# thickness_map min/mean/max = 21.39, 99.88, 186.14
# Layer 32, depth_maps.shape = (300, 300, 33)
# Building Layer 33
#  1.0, 0.33380431511775055,  1.5830481312211295,  0.27007582887325543
# azi, dip, dipping_plane min/mean/max = 312.91010406432633, 0.0007619514893462132, 0.00, 0.00, 0.01
# current_depth_map min/mean/max = 10761.85, 11081.54, 11544.39
# thickness_map min/mean/max = 16.56, 49.62, 78.53
# Layer 33, depth_maps.shape = (300, 300, 34)
# Building Layer 34
#  1.0, 0.6072991533450394,  1.4496665841841432,  0.19356845864401268
# azi, dip, dipping_plane min/mean/max = 61.555088482612575, 0.04619324948788406, 0.00, 0.23, 0.46
# current_depth_map min/mean/max = 10729.36, 11038.73, 11511.35
# thickness_map min/mean/max = 25.96, 42.82, 62.24
# Layer 34, depth_maps.shape = (300, 300, 35)
# Building Layer 35
#  1.0, 0.16871327934126024,  1.7113042699989878,  0.4177846033879072
# azi, dip, dipping_plane min/mean/max = 332.81349349684064, 0.15435076952827953, 0.00, 0.77, 1.53
# current_depth_map min/mean/max = 10656.85, 10979.15, 11425.79
# thickness_map min/mean/max = 10.66, 59.58, 110.13
# Layer 35, depth_maps.shape = (300, 300, 36)
# Building Layer 36
#  1.0, 0.15006438242644538,  1.9158637370478533,  0.404609738875554
# azi, dip, dipping_plane min/mean/max = 65.97942355545182, 0.19741883823099005, 0.00, 0.96, 1.92
# current_depth_map min/mean/max = 10616.32, 10935.08, 11391.49
# thickness_map min/mean/max = 5.55, 44.07, 93.81
# Layer 36, depth_maps.shape = (300, 300, 37)
# Building Layer 37
#  1.0, 0.4724788676594218,  1.9217413074624732,  0.3217295176758126
# azi, dip, dipping_plane min/mean/max = 181.34114853031113, 0.014662735650704972, 0.00, 0.06, 0.11
# current_depth_map min/mean/max = 10510.33, 10868.44, 11281.17
# thickness_map min/mean/max = 31.47, 66.64, 129.07
# Layer 37, depth_maps.shape = (300, 300, 38)
# Building Layer 38
#  1.0, 0.21108390912020092,  1.6656995112674593,  0.32547984023441007
# azi, dip, dipping_plane min/mean/max = 35.36190916669445, 0.3706387630056047, 0.00, 1.91, 3.81
# current_depth_map min/mean/max = 10445.85, 10789.34, 11206.39
# thickness_map min/mean/max = 13.49, 79.10, 152.72
# Layer 38, depth_maps.shape = (300, 300, 39)
# Building Layer 39
#  1.0, 0.06525305730772024,  1.8438778199296257,  0.40174290981750294
# azi, dip, dipping_plane min/mean/max = 329.2132830608071, 0.30240474305476284, 0.00, 1.53, 3.06
# current_depth_map min/mean/max = 10348.79, 10710.46, 11083.01
# thickness_map min/mean/max = 5.83, 78.88, 150.60
# Layer 39, depth_maps.shape = (300, 300, 40)
# Building Layer 40
#  1.0, 0.3503162454226396,  1.8736500543655246,  0.39277882347296944
# azi, dip, dipping_plane min/mean/max = 94.70898497565823, 0.05001359315874643, 0.00, 0.20, 0.40
# current_depth_map min/mean/max = 10283.04, 10619.85, 11019.93
# thickness_map min/mean/max = 31.25, 90.61, 170.43
# Layer 40, depth_maps.shape = (300, 300, 41)
# Building Layer 41
#  1.0, 0.36219902066001797,  1.8669908896381902,  0.27222470808329413
# azi, dip, dipping_plane min/mean/max = 255.76681600647632, 0.014096843181617635, 0.00, 0.06, 0.13
# current_depth_map min/mean/max = 10225.59, 10564.38, 10967.13
# thickness_map min/mean/max = 20.03, 55.47, 104.52
# Layer 41, depth_maps.shape = (300, 300, 42)
# Building Layer 42
#  1.0, 0.34966355044974096,  1.4485108019363322,  0.20965214620110592
# azi, dip, dipping_plane min/mean/max = 91.31772683119195, 0.12318978380937018, 0.00, 0.46, 0.93
# current_depth_map min/mean/max = 10189.12, 10520.50, 10938.40
# thickness_map min/mean/max = 13.69, 43.88, 61.65
# Layer 42, depth_maps.shape = (300, 300, 43)
# Building Layer 43
#  1.0, 0.4047274332290104,  1.4301765866807306,  0.2506726970829026
# azi, dip, dipping_plane min/mean/max = 17.90731081992085, 0.18478677880256078, 0.00, 0.86, 1.72
# current_depth_map min/mean/max = 10130.80, 10444.43, 10873.48
# thickness_map min/mean/max = 30.88, 76.07, 107.58
# Layer 43, depth_maps.shape = (300, 300, 44)
# Building Layer 44
#  1.0, 0.41925950721713934,  1.3433462173440418,  0.22893154855875103
# azi, dip, dipping_plane min/mean/max = 18.715472784420875, 0.01661238473539617, 0.00, 0.08, 0.16
# current_depth_map min/mean/max = 10088.16, 10389.83, 10835.99
# thickness_map min/mean/max = 23.15, 54.60, 72.85
# Layer 44, depth_maps.shape = (300, 300, 45)
# Building Layer 45
#  1.0, 0.31821194768147,  1.3766863847870696,  0.24171473926172796
# azi, dip, dipping_plane min/mean/max = 348.95973151638344, 0.0039142474799900295, 0.00, 0.02, 0.03
# current_depth_map min/mean/max = 10033.62, 10334.59, 10781.55
# thickness_map min/mean/max = 17.61, 55.24, 75.91
# Layer 45, depth_maps.shape = (300, 300, 46)
# Building Layer 46
#  1.0000000000000002, 0.36082827881598145,  1.6854924662935185,  0.2884929779079539
# azi, dip, dipping_plane min/mean/max = 178.0155846450044, 0.034612757735990596, 0.00, 0.13, 0.26
# current_depth_map min/mean/max = 9959.51, 10250.47, 10712.31
# thickness_map min/mean/max = 29.83, 84.12, 142.97
# Layer 46, depth_maps.shape = (300, 300, 47)
# Building Layer 47
#  0.9999999999999999, 0.30747036941238837,  1.8496107896761877,  0.3975942696128906
# azi, dip, dipping_plane min/mean/max = 333.5077620821083, 0.031045391888096074, 0.00, 0.15, 0.31
# current_depth_map min/mean/max = 9877.42, 10203.82, 10631.69
# thickness_map min/mean/max = 14.55, 46.65, 85.36
# Layer 47, depth_maps.shape = (300, 300, 48)
# Building Layer 48
#  1.0, 0.2944051380643876,  1.588141951514909,  0.28300378267355547
# azi, dip, dipping_plane min/mean/max = 163.81786515842373, 0.07802935786187404, 0.00, 0.36, 0.71
# current_depth_map min/mean/max = 9855.68, 10181.33, 10623.97
# thickness_map min/mean/max = 5.60, 22.49, 36.79
# Layer 48, depth_maps.shape = (300, 300, 49)
# Building Layer 49
#  1.0, 0.2801312072938563,  1.6798116182280105,  0.27626352057861636
# azi, dip, dipping_plane min/mean/max = 181.1926753559548, 0.03417862599731869, 0.00, 0.13, 0.26
# current_depth_map min/mean/max = 9760.54, 10121.29, 10555.02
# thickness_map min/mean/max = 16.50, 60.04, 102.77
# Layer 49, depth_maps.shape = (300, 300, 50)
# Building Layer 50
#  1.0, 0.3862957908866582,  1.8220450134708965,  0.3231917842012356
# azi, dip, dipping_plane min/mean/max = 201.64947967299148, 0.009342499185400088, 0.00, 0.04, 0.09
# current_depth_map min/mean/max = 9704.92, 10061.80, 10513.85
# thickness_map min/mean/max = 22.88, 59.49, 108.97
# Layer 50, depth_maps.shape = (300, 300, 51)
# Building Layer 51
#  1.0000000000000002, 0.32770087979606266,  1.7426569809948342,  0.4090037039392625
# azi, dip, dipping_plane min/mean/max = 134.8865100036882, 0.3941626953718338, 0.00, 2.06, 4.11
# current_depth_map min/mean/max = 9610.46, 9997.46, 10480.07
# thickness_map min/mean/max = 23.35, 64.34, 108.25
# Layer 51, depth_maps.shape = (300, 300, 52)
# Building Layer 52
#  1.0, 0.22718779549233536,  1.6708933565630142,  0.28956429890811464
# azi, dip, dipping_plane min/mean/max = 251.9297986596263, 0.01579335827758299, 0.00, 0.07, 0.15
# current_depth_map min/mean/max = 9533.98, 9938.60, 10425.12
# thickness_map min/mean/max = 13.48, 58.86, 99.43
# Layer 52, depth_maps.shape = (300, 300, 53)
# Building Layer 53
#  1.0000000000000002, 0.506230146662864,  1.3782666369139382,  0.206271984230384
# azi, dip, dipping_plane min/mean/max = 10.380459880098059, 0.028127560804100615, 0.00, 0.12, 0.24
# current_depth_map min/mean/max = 9438.87, 9859.33, 10355.74
# thickness_map min/mean/max = 40.62, 79.27, 108.87
# Layer 53, depth_maps.shape = (300, 300, 54)
# Building Layer 54
#  1.0, 0.3881928119036471,  1.905637936822906,  0.3760399305513532
# azi, dip, dipping_plane min/mean/max = 73.8684152699393, 0.032271544656724105, 0.00, 0.15, 0.29
# current_depth_map min/mean/max = 9395.18, 9812.32, 10293.00
# thickness_map min/mean/max = 18.58, 47.01, 88.45
# Layer 54, depth_maps.shape = (300, 300, 55)
# Building Layer 55
#  1.0000000000000002, 0.12474281743046223,  1.7006753715700311,  0.345086514847875
# azi, dip, dipping_plane min/mean/max = 178.0552354743236, 0.03234977051146548, 0.00, 0.12, 0.25
# current_depth_map min/mean/max = 9334.72, 9768.68, 10241.41
# thickness_map min/mean/max = 5.40, 43.65, 75.07
# Layer 55, depth_maps.shape = (300, 300, 56)
# Building Layer 56
#  1.0000000000000002, 0.33489930586958294,  1.566940855254658,  0.35957266709536156
# azi, dip, dipping_plane min/mean/max = 43.118070513808576, 0.040168748562081524, 0.00, 0.21, 0.42
# current_depth_map min/mean/max = 9304.51, 9730.62, 10204.16
# thickness_map min/mean/max = 12.37, 38.06, 60.67
# Layer 56, depth_maps.shape = (300, 300, 57)
# Building Layer 57
#  1.0, 0.4433085696114799,  1.4894095285978322,  0.26642020343789796
# azi, dip, dipping_plane min/mean/max = 263.40452710989626, 0.01192170610795018, 0.00, 0.05, 0.10
# current_depth_map min/mean/max = 9241.08, 9676.15, 10162.56
# thickness_map min/mean/max = 24.15, 54.47, 81.05
# Layer 57, depth_maps.shape = (300, 300, 58)
# Building Layer 58
#  1.0, 0.43175810654152813,  1.5237707661697544,  0.23909206896200652
# azi, dip, dipping_plane min/mean/max = 222.86650306921265, 0.0171509537053377, 0.00, 0.09, 0.18
# current_depth_map min/mean/max = 9207.82, 9639.05, 10130.42
# thickness_map min/mean/max = 15.86, 37.10, 57.37
# Layer 58, depth_maps.shape = (300, 300, 59)
# Building Layer 59
#  1.0, 0.3555805410781522,  1.5380534597815139,  0.32983888799270616
# azi, dip, dipping_plane min/mean/max = 177.46098981667748, 0.01567060167636658, 0.00, 0.06, 0.12
# current_depth_map min/mean/max = 9162.43, 9600.90, 10103.75
# thickness_map min/mean/max = 13.33, 38.14, 59.03
# Layer 59, depth_maps.shape = (300, 300, 60)
# Building Layer 60
#  1.0, 0.5016396895823632,  1.4576979369630816,  0.18838051317837726
# azi, dip, dipping_plane min/mean/max = 148.64845225949358, 0.08983639647064279, 0.00, 0.46, 0.91
# current_depth_map min/mean/max = 9129.21, 9562.94, 10069.36
# thickness_map min/mean/max = 20.36, 37.96, 59.07
# Layer 60, depth_maps.shape = (300, 300, 61)
# Building Layer 61
#  1.0, 0.5867545056916732,  1.4540030967596453,  0.1988715771032266
# azi, dip, dipping_plane min/mean/max = 99.09181271315322, 0.022714862037933825, 0.00, 0.10, 0.19
# current_depth_map min/mean/max = 9091.85, 9523.48, 10025.67
# thickness_map min/mean/max = 23.53, 39.47, 56.32
# Layer 61, depth_maps.shape = (300, 300, 62)
# Building Layer 62
#  1.0, 0.48349138385789536,  1.5556167589855354,  0.31963467089960756
# azi, dip, dipping_plane min/mean/max = 32.29210575940052, 0.011032077647442073, 0.00, 0.06, 0.11
# current_depth_map min/mean/max = 9012.12, 9461.86, 9982.07
# thickness_map min/mean/max = 29.95, 61.62, 95.54
# Layer 62, depth_maps.shape = (300, 300, 63)
# Building Layer 63
#  1.0, 0.20938233172352627,  1.8361255216018726,  0.30616381521874214
# azi, dip, dipping_plane min/mean/max = 162.16083505067064, 0.03367561150563003, 0.00, 0.16, 0.31
# current_depth_map min/mean/max = 8949.94, 9411.28, 9924.41
# thickness_map min/mean/max = 10.56, 50.58, 90.92
# Layer 63, depth_maps.shape = (300, 300, 64)
# Building Layer 64
#  1.0, 0.2775271598036644,  1.9792327339390239,  0.4959461600038375
# azi, dip, dipping_plane min/mean/max = 190.05265737126464, 0.034359369775117, 0.00, 0.15, 0.29
# current_depth_map min/mean/max = 8886.48, 9375.08, 9877.20
# thickness_map min/mean/max = 10.12, 36.20, 69.22
# Layer 64, depth_maps.shape = (300, 300, 65)
# Building Layer 65
#  1.0000000000000002, 0.036480743121692916,  1.6466445377747203,  0.34336639889027476
# azi, dip, dipping_plane min/mean/max = 236.71289494125418, 0.04785007313968692, 0.00, 0.24, 0.49
# current_depth_map min/mean/max = 8809.37, 9278.52, 9861.34
# thickness_map min/mean/max = 3.53, 96.56, 157.68
# Layer 65, depth_maps.shape = (300, 300, 66)
# Building Layer 66
#  0.9999999999999999, 0.11055068215352226,  1.7278920228241215,  0.445855903929145
# azi, dip, dipping_plane min/mean/max = 245.5101444535221, 0.0905893361706287, 0.00, 0.44, 0.89
# current_depth_map min/mean/max = 8801.22, 9247.49, 9857.46
# thickness_map min/mean/max = 3.23, 31.03, 52.98
# Layer 66, depth_maps.shape = (300, 300, 67)
# Building Layer 67
#  1.0000000000000002, 0.40076886154955116,  1.864833900301209,  0.30493699270396873
# azi, dip, dipping_plane min/mean/max = 76.93611078551915, 0.03759481899280537, 0.00, 0.17, 0.33
# current_depth_map min/mean/max = 8662.37, 9172.66, 9807.77
# thickness_map min/mean/max = 29.91, 74.84, 140.10
# Layer 67, depth_maps.shape = (300, 300, 68)
# Building Layer 68
#  1.0, 0.20486081561354352,  1.6862246235697422,  0.3775346338308799
# azi, dip, dipping_plane min/mean/max = 164.16795487111042, 0.000622784491849826, 0.00, 0.00, 0.01
# current_depth_map min/mean/max = 8606.95, 9107.53, 9775.23
# thickness_map min/mean/max = 13.34, 65.13, 109.82
# Layer 68, depth_maps.shape = (300, 300, 69)
# Building Layer 69
#  1.0, 0.4396507888379434,  1.474659657813517,  0.2765342066752778
# azi, dip, dipping_plane min/mean/max = 84.58919782882077, 0.02879925108757808, 0.00, 0.12, 0.23
# current_depth_map min/mean/max = 8534.39, 9038.96, 9696.25
# thickness_map min/mean/max = 29.64, 68.57, 101.03
# Layer 69, depth_maps.shape = (300, 300, 70)
# Building Layer 70
#  1.0, 0.4937436279812263,  1.5860350182637837,  0.2581275782877343
# azi, dip, dipping_plane min/mean/max = 353.4733244576454, 0.012858569665956221, 0.00, 0.05, 0.11
# current_depth_map min/mean/max = 8446.62, 8954.97, 9611.42
# thickness_map min/mean/max = 41.63, 83.99, 133.35
# Layer 70, depth_maps.shape = (300, 300, 71)
# Building Layer 71
#  1.0, 0.1450064430184006,  2.0515331518342994,  0.4186485558997223
# azi, dip, dipping_plane min/mean/max = 102.6494115866391, 0.11219908546864654, 0.00, 0.49, 0.99
# current_depth_map min/mean/max = 8278.37, 8864.95, 9484.93
# thickness_map min/mean/max = 13.22, 90.02, 177.54
# Layer 71, depth_maps.shape = (300, 300, 72)
# Building Layer 72
#  1.0000000000000002, 0.14183201450554228,  1.8663162130066453,  0.4639169180324784
# azi, dip, dipping_plane min/mean/max = 259.65518470848895, 0.14383125906035166, 0.00, 0.62, 1.23
# current_depth_map min/mean/max = 8252.63, 8828.03, 9470.26
# thickness_map min/mean/max = 5.57, 36.92, 71.76
# Layer 72, depth_maps.shape = (300, 300, 73)
# Building Layer 73
#  1.0, 0.2656707726654729,  1.8690053505381166,  0.36707358591029815
# azi, dip, dipping_plane min/mean/max = 96.67699675239399, 0.20832783564004365, 0.00, 0.85, 1.71
# current_depth_map min/mean/max = 8160.84, 8779.75, 9409.79
# thickness_map min/mean/max = 10.86, 48.28, 96.24
# Layer 73, depth_maps.shape = (300, 300, 74)
# Building Layer 74
#  1.0000000000000002, 0.5367691081821926,  1.6553199604004227,  0.2575573845909191
# azi, dip, dipping_plane min/mean/max = 303.10073464763457, 0.10594022232459621, 0.00, 0.54, 1.08
# current_depth_map min/mean/max = 8123.31, 8729.58, 9342.88
# thickness_map min/mean/max = 27.86, 50.17, 84.77
# Layer 74, depth_maps.shape = (300, 300, 75)
# Building Layer 75
#  1.0, 0.43055132052048284,  1.796721083145405,  0.30197376486966676
# azi, dip, dipping_plane min/mean/max = 23.589148427384842, 0.007533186059499375, 0.00, 0.04, 0.07
# current_depth_map min/mean/max = 8058.26, 8681.65, 9291.72
# thickness_map min/mean/max = 20.70, 47.93, 85.94
# Layer 75, depth_maps.shape = (300, 300, 76)
# Building Layer 76
#  1.0, 0.29984382335465054,  1.9378457652974326,  0.36871952414413806
# azi, dip, dipping_plane min/mean/max = 201.66812140623193, 0.32542947645506426, 0.00, 1.56, 3.12
# current_depth_map min/mean/max = 7990.18, 8591.06, 9184.18
# thickness_map min/mean/max = 27.31, 90.59, 191.00
# Layer 76, depth_maps.shape = (300, 300, 77)
# Building Layer 77
#  1.0, 0.32440161053654226,  1.781212669687052,  0.35164139741828976
# azi, dip, dipping_plane min/mean/max = 171.24875681837443, 0.05000894251999455, 0.00, 0.21, 0.42
# current_depth_map min/mean/max = 7885.57, 8512.75, 9145.83
# thickness_map min/mean/max = 24.87, 78.31, 141.38
# Layer 77, depth_maps.shape = (300, 300, 78)
# Building Layer 78
#  1.0, 0.25762524177652124,  1.6628229878093812,  0.3195440308708704
# azi, dip, dipping_plane min/mean/max = 91.5669622394623, 0.11731741069877155, 0.00, 0.44, 0.89
# current_depth_map min/mean/max = 7832.95, 8442.28, 9065.16
# thickness_map min/mean/max = 19.35, 70.47, 115.49
# Layer 78, depth_maps.shape = (300, 300, 79)
# Building Layer 79
#  1.0, 0.20580658333414803,  1.918298866557125,  0.39143420853395355
# azi, dip, dipping_plane min/mean/max = 328.86262428779077, 0.08403084119530124, 0.00, 0.43, 0.85
# current_depth_map min/mean/max = 7814.15, 8370.11, 8985.00
# thickness_map min/mean/max = 14.11, 72.17, 134.01
# Layer 79, depth_maps.shape = (300, 300, 80)
# Building Layer 80
#  1.0, 0.6368221546497693,  1.5869894770544763,  0.19410744447584247
# azi, dip, dipping_plane min/mean/max = 251.88533755107085, 0.006767351733445226, 0.00, 0.03, 0.06
# current_depth_map min/mean/max = 7770.96, 8328.61, 8937.41
# thickness_map min/mean/max = 26.60, 41.50, 65.44
# Layer 80, depth_maps.shape = (300, 300, 81)
# Building Layer 81
#  1.0, 0.45130528335202813,  1.5667412723274683,  0.1846024411464414
# azi, dip, dipping_plane min/mean/max = 54.82276654100383, 0.10751635318829567, 0.00, 0.55, 1.11
# current_depth_map min/mean/max = 7688.28, 8248.24, 8860.00
# thickness_map min/mean/max = 34.47, 80.37, 120.29
# Layer 81, depth_maps.shape = (300, 300, 82)
# Building Layer 82
#  0.9999999999999999, 0.3748239186176693,  1.6047614690872432,  0.31715234170665496
# azi, dip, dipping_plane min/mean/max = 345.3967986204099, 0.07931389582073489, 0.00, 0.36, 0.71
# current_depth_map min/mean/max = 7651.34, 8212.08, 8844.61
# thickness_map min/mean/max = 14.20, 36.16, 56.27
# Layer 82, depth_maps.shape = (300, 300, 83)
# Building Layer 83
#  1.0, 0.4919782005111569,  1.491765313895836,  0.2253257051415771
# azi, dip, dipping_plane min/mean/max = 224.0510859250572, 0.07214329619469895, 0.00, 0.38, 0.75
# current_depth_map min/mean/max = 7561.64, 8151.30, 8799.87
# thickness_map min/mean/max = 30.69, 60.78, 92.84
# Layer 83, depth_maps.shape = (300, 300, 84)
# Building Layer 84
#  1.0, 0.5626393767663485,  1.6981948878915196,  0.2591969663517915
# azi, dip, dipping_plane min/mean/max = 198.66323975720334, 0.02971898671487272, 0.00, 0.14, 0.28
# current_depth_map min/mean/max = 7531.66, 8117.01, 8765.10
# thickness_map min/mean/max = 18.72, 34.29, 58.86
# Layer 84, depth_maps.shape = (300, 300, 85)
# Building Layer 85
#  1.0, 0.5276390028051902,  1.4328067916106957,  0.19139897051354363
# azi, dip, dipping_plane min/mean/max = 94.96279141790802, 0.15233746169033724, 0.00, 0.61, 1.22
# current_depth_map min/mean/max = 7448.51, 8045.96, 8701.74
# thickness_map min/mean/max = 34.41, 71.06, 103.09
# Layer 85, depth_maps.shape = (300, 300, 86)
# Building Layer 86
#  1.0000000000000002, 0.11720881813139405,  1.859628115815462,  0.43245160487555223
# azi, dip, dipping_plane min/mean/max = 202.32235431887764, 0.033698433660860005, 0.00, 0.16, 0.32
# current_depth_map min/mean/max = 7397.62, 7964.34, 8619.09
# thickness_map min/mean/max = 9.71, 81.62, 150.69
# Layer 86, depth_maps.shape = (300, 300, 87)
# Building Layer 87
#  0.9999999999999997, 0.37650783968064305,  1.6618429678894842,  0.3094350950321381
# azi, dip, dipping_plane min/mean/max = 290.49378780696185, 0.1378908233050512, 0.00, 0.65, 1.31
# current_depth_map min/mean/max = 7279.66, 7837.38, 8469.12
# thickness_map min/mean/max = 46.37, 126.96, 210.28
# Layer 87, depth_maps.shape = (300, 300, 88)
# Building Layer 88
#  0.9999999999999999, 0.6473038963840337,  1.4814531492100247,  0.19376108833074077
# azi, dip, dipping_plane min/mean/max = 181.54633497232717, 0.054076469252224535, 0.00, 0.20, 0.41
# current_depth_map min/mean/max = 7228.75, 7797.05, 8425.78
# thickness_map min/mean/max = 26.15, 40.33, 61.01
# Layer 88, depth_maps.shape = (300, 300, 89)
# Building Layer 89
#  1.0, 0.5605918718039522,  1.3685974343554592,  0.2083529600739292
# azi, dip, dipping_plane min/mean/max = 71.63798607995386, 0.06050931509157753, 0.00, 0.28, 0.56
# current_depth_map min/mean/max = 7173.68, 7733.63, 8377.70
# thickness_map min/mean/max = 34.41, 63.42, 88.79
# Layer 89, depth_maps.shape = (300, 300, 90)
# Building Layer 90
#  1.0, 0.013544044997095162,  1.7325279024433413,  0.3756812822166705
# azi, dip, dipping_plane min/mean/max = 229.89277637402427, 0.0062418473623826465, 0.00, 0.03, 0.06
# current_depth_map min/mean/max = 7075.87, 7633.10, 8327.00
# thickness_map min/mean/max = 1.36, 100.53, 174.16
# Layer 90, depth_maps.shape = (300, 300, 91)
# Building Layer 91
#  0.9999999999999999, 0.31077857798557695,  1.7269401457460476,  0.41619875914704824
# azi, dip, dipping_plane min/mean/max = 274.11978331396995, 0.12889315887564057, 0.00, 0.51, 1.02
# current_depth_map min/mean/max = 7061.53, 7593.45, 8287.50
# thickness_map min/mean/max = 11.22, 39.64, 68.61
# Layer 91, depth_maps.shape = (300, 300, 92)
# Building Layer 92
#  1.0000000000000002, 0.614000839103346,  1.7451576961511122,  0.2321083668128688
# azi, dip, dipping_plane min/mean/max = 330.53240842409923, 0.045836631429785446, 0.00, 0.23, 0.46
# current_depth_map min/mean/max = 6975.24, 7505.35, 8148.00
# thickness_map min/mean/max = 53.36, 88.10, 156.62
# Layer 92, depth_maps.shape = (300, 300, 93)
# Building Layer 93
#  1.0, 0.4750348676938829,  1.3923115619128015,  0.20285937944194823
# azi, dip, dipping_plane min/mean/max = 59.81499576837065, 0.014476267281204769, 0.00, 0.07, 0.15
# current_depth_map min/mean/max = 6943.24, 7468.01, 8108.75
# thickness_map min/mean/max = 17.90, 37.34, 51.40
# Layer 93, depth_maps.shape = (300, 300, 94)
# Building Layer 94
#  0.9999999999999999, 0.526967353297827,  1.5535635648672255,  0.2778096360918459
# azi, dip, dipping_plane min/mean/max = 352.22556948295414, 0.06740118642307735, 0.00, 0.28, 0.56
# current_depth_map min/mean/max = 6902.92, 7435.98, 8081.36
# thickness_map min/mean/max = 17.67, 32.03, 47.24
# Layer 94, depth_maps.shape = (300, 300, 95)
# Building Layer 95
#  1.0, 0.2503942313981776,  1.6024894373426402,  0.3300208669210142
# azi, dip, dipping_plane min/mean/max = 276.74171714097207, 0.007501086248032585, 0.00, 0.03, 0.06
# current_depth_map min/mean/max = 6863.08, 7390.89, 8059.18
# thickness_map min/mean/max = 11.21, 45.09, 72.25
# Layer 95, depth_maps.shape = (300, 300, 96)
# Building Layer 96
#  1.0, 0.41342827078696487,  1.5651979225210164,  0.28375535620044046
# azi, dip, dipping_plane min/mean/max = 70.74017903635063, 0.0011264353846354158, 0.00, 0.01, 0.01
# current_depth_map min/mean/max = 6797.01, 7337.49, 8002.54
# thickness_map min/mean/max = 22.10, 53.40, 83.62
# Layer 96, depth_maps.shape = (300, 300, 97)
# Building Layer 97
#  1.0, 0.627639757951215,  1.4704021472880666,  0.1749672245959426
# azi, dip, dipping_plane min/mean/max = 91.92481632895057, 0.3663963531860719, 0.00, 1.40, 2.79
# current_depth_map min/mean/max = 6758.67, 7308.64, 7986.46
# thickness_map min/mean/max = 14.16, 28.84, 61.95
# Layer 97, depth_maps.shape = (300, 300, 98)
# Building Layer 98
#  1.0, 0.37128587676486113,  1.6824144518035395,  0.33786996153112897
# azi, dip, dipping_plane min/mean/max = 36.72410702251551, 0.14196088397775242, 0.00, 0.73, 1.47
# current_depth_map min/mean/max = 6725.53, 7248.38, 7909.49
# thickness_map min/mean/max = 23.99, 60.26, 96.33
# Layer 98, depth_maps.shape = (300, 300, 99)
# Building Layer 99
#  1.0, 0.4909647046064687,  1.8850818202734816,  0.2986933784099202
# azi, dip, dipping_plane min/mean/max = 79.17438903143137, 0.021761904501454543, 0.00, 0.09, 0.19
# current_depth_map min/mean/max = 6673.04, 7210.67, 7872.47
# thickness_map min/mean/max = 18.22, 37.72, 70.56
# Layer 99, depth_maps.shape = (300, 300, 100)
# Building Layer 100
#  1.0, 0.35079470917160416,  1.6967870595898091,  0.30556230230137926
# azi, dip, dipping_plane min/mean/max = 93.01598143812046, 0.007214478703860383, 0.00, 0.03, 0.06
# current_depth_map min/mean/max = 6628.21, 7147.50, 7797.85
# thickness_map min/mean/max = 22.23, 63.16, 106.90
# Layer 100, depth_maps.shape = (300, 300, 101)
# Building Layer 101
#  1.0000000000000002, 0.41040838029502236,  1.353945188511316,  0.2051836365931577
# azi, dip, dipping_plane min/mean/max = 280.77281742619033, 0.012176020345609384, 0.00, 0.05, 0.11
# current_depth_map min/mean/max = 6590.72, 7100.74, 7746.67
# thickness_map min/mean/max = 19.03, 46.76, 63.76
# Layer 101, depth_maps.shape = (300, 300, 102)
# Building Layer 102
#  1.0000000000000002, 0.4582607632356409,  1.6398864315511248,  0.2688614334784922
# azi, dip, dipping_plane min/mean/max = 236.77964043863818, 0.0011939462193397699, 0.00, 0.01, 0.01
# current_depth_map min/mean/max = 6543.17, 7045.02, 7668.21
# thickness_map min/mean/max = 25.55, 55.72, 91.33
# Layer 102, depth_maps.shape = (300, 300, 103)
# Building Layer 103
#  1.0, 0.529187024591237,  1.652326505368786,  0.2575739147775533
# azi, dip, dipping_plane min/mean/max = 305.66569593281207, 0.08778653612670562, 0.00, 0.45, 0.90
# current_depth_map min/mean/max = 6404.38, 6953.04, 7614.06
# thickness_map min/mean/max = 50.29, 91.98, 148.62
# Layer 103, depth_maps.shape = (300, 300, 104)
# Building Layer 104
#  1.0, 0.1436144720233673,  1.7327352381400862,  0.4428723060889137
# azi, dip, dipping_plane min/mean/max = 86.57707815115859, 0.08316369388530886, 0.00, 0.32, 0.65
# current_depth_map min/mean/max = 6307.73, 6885.73, 7555.78
# thickness_map min/mean/max = 9.14, 67.31, 116.82
# Layer 104, depth_maps.shape = (300, 300, 105)
# Building Layer 105
#  1.0, 0.18285653488661047,  1.84824966837256,  0.4562660379668629
# azi, dip, dipping_plane min/mean/max = 105.4987523800472, 0.09606411750425736, 0.00, 0.44, 0.87
# current_depth_map min/mean/max = 6234.39, 6840.58, 7504.66
# thickness_map min/mean/max = 8.86, 45.15, 85.33
# Layer 105, depth_maps.shape = (300, 300, 106)
# Building Layer 106
#  1.0, 0.22536087585786202,  1.6980620847672263,  0.35053382425288643
# azi, dip, dipping_plane min/mean/max = 95.29788036866634, 0.033959041821147284, 0.00, 0.14, 0.27
# current_depth_map min/mean/max = 6160.09, 6787.51, 7476.09
# thickness_map min/mean/max = 11.78, 53.07, 88.40
# Layer 106, depth_maps.shape = (300, 300, 107)
# Building Layer 107
#  1.0, 0.3686835884921643,  1.6972360460202753,  0.32401845047414907
# azi, dip, dipping_plane min/mean/max = 310.61215556135386, 0.15585494488320284, 0.00, 0.81, 1.62
# current_depth_map min/mean/max = 6106.36, 6732.75, 7401.73
# thickness_map min/mean/max = 21.05, 54.77, 90.78
# Layer 107, depth_maps.shape = (300, 300, 108)
# Building Layer 108
#  1.0, 0.18022983873433618,  1.926068406401877,  0.5130061500001586
# azi, dip, dipping_plane min/mean/max = 201.94473041930013, 0.02272794742681139, 0.00, 0.11, 0.22
# current_depth_map min/mean/max = 6023.81, 6683.52, 7365.02
# thickness_map min/mean/max = 8.76, 49.23, 95.68
# Layer 108, depth_maps.shape = (300, 300, 109)
# Building Layer 109
#  1.0, 0.3820429091308494,  1.5954747001575114,  0.29154795394380684
# azi, dip, dipping_plane min/mean/max = 140.88182752303055, 0.06536324827874918, 0.00, 0.34, 0.68
# current_depth_map min/mean/max = 5970.92, 6635.94, 7329.95
# thickness_map min/mean/max = 17.27, 47.58, 76.28
# Layer 109, depth_maps.shape = (300, 300, 110)
# Building Layer 110
#  1.0, 0.052545083497621214,  1.5041298953002604,  0.3343544274109472
# azi, dip, dipping_plane min/mean/max = 206.1450975640678, 0.04457249331721802, 0.00, 0.22, 0.44
# current_depth_map min/mean/max = 5940.19, 6590.10, 7296.53
# thickness_map min/mean/max = 2.36, 45.85, 68.73
# Layer 110, depth_maps.shape = (300, 300, 111)
# Building Layer 111
#  1.0, 0.4245726102355938,  1.6355293967964895,  0.27968125616722433
# azi, dip, dipping_plane min/mean/max = 115.83382544670133, 0.01688371594860738, 0.00, 0.08, 0.17
# current_depth_map min/mean/max = 5870.87, 6499.37, 7209.33
# thickness_map min/mean/max = 38.63, 90.72, 147.90
# Layer 111, depth_maps.shape = (300, 300, 112)
# Building Layer 112
#  0.9999999999999999, 0.48450096163946,  1.4566266390386002,  0.2151872372984661
# azi, dip, dipping_plane min/mean/max = 94.39035993546649, 0.04680678095780877, 0.00, 0.19, 0.37
# current_depth_map min/mean/max = 5833.73, 6452.51, 7168.09
# thickness_map min/mean/max = 22.37, 46.87, 66.88
# Layer 112, depth_maps.shape = (300, 300, 113)
# Building Layer 113
#  1.0000000000000002, 0.357647962773491,  1.5931697310267652,  0.2654483069558818
# azi, dip, dipping_plane min/mean/max = 114.25966050542756, 0.003376870907716323, 0.00, 0.02, 0.03
# current_depth_map min/mean/max = 5758.39, 6374.39, 7104.93
# thickness_map min/mean/max = 27.96, 78.12, 124.38
# Layer 113, depth_maps.shape = (300, 300, 114)
# Building Layer 114
#  1.0, 0.4125859460063648,  1.7045301784800557,  0.2697011971452049
# azi, dip, dipping_plane min/mean/max = 350.0046493884213, 0.08900555888957207, 0.00, 0.38, 0.76
# current_depth_map min/mean/max = 5694.25, 6313.99, 7011.86
# thickness_map min/mean/max = 25.27, 60.40, 108.35
# Layer 114, depth_maps.shape = (300, 300, 115)
# Building Layer 115
#  1.0000000000000002, 0.08113191175404066,  1.8465547006018714,  0.43956875008390917
# azi, dip, dipping_plane min/mean/max = 300.51805360932684, 0.06633975683097348, 0.00, 0.34, 0.67
# current_depth_map min/mean/max = 5612.48, 6261.44, 6963.25
# thickness_map min/mean/max = 4.31, 52.55, 97.00
# Layer 115, depth_maps.shape = (300, 300, 116)
# Building Layer 116
#  1.0, 0.41386161237293895,  1.3963343034733096,  0.19091079992502147
# azi, dip, dipping_plane min/mean/max = 59.053411648234515, 0.09271479917174019, 0.00, 0.47, 0.94
# current_depth_map min/mean/max = 5570.61, 6228.07, 6928.07
# thickness_map min/mean/max = 15.21, 33.37, 47.74
# Layer 116, depth_maps.shape = (300, 300, 117)
# Building Layer 117
#  0.9999999999999999, 0.42633052676211414,  1.7592970020722971,  0.2639946189520431
# azi, dip, dipping_plane min/mean/max = 117.70036187722351, 0.11480036902363466, 0.00, 0.57, 1.14
# current_depth_map min/mean/max = 5544.49, 6176.80, 6885.31
# thickness_map min/mean/max = 22.66, 51.27, 83.15
# Layer 117, depth_maps.shape = (300, 300, 118)
# Building Layer 118
#  1.0, 0.4470919064926201,  1.4235711913961924,  0.23097693950735246
# azi, dip, dipping_plane min/mean/max = 297.08839059283696, 0.06749246425004873, 0.00, 0.34, 0.67
# current_depth_map min/mean/max = 5530.24, 6148.67, 6845.06
# thickness_map min/mean/max = 11.55, 28.13, 42.85
# Layer 118, depth_maps.shape = (300, 300, 119)
# Building Layer 119
#  1.0, 0.15624548449384434,  1.8311693070304564,  0.3959564831824814
# azi, dip, dipping_plane min/mean/max = 43.052737476586344, 0.014130488054708401, 0.00, 0.07, 0.15
# current_depth_map min/mean/max = 5431.29, 6057.75, 6782.81
# thickness_map min/mean/max = 14.29, 90.92, 166.28
# Layer 119, depth_maps.shape = (300, 300, 120)
# Building Layer 120
#  1.0, 0.4887739577520509,  1.492597721006499,  0.24730671543210908
# azi, dip, dipping_plane min/mean/max = 152.81278929990145, 0.13758478378736538, 0.00, 0.68, 1.37
# current_depth_map min/mean/max = 5380.14, 5996.40, 6717.28
# thickness_map min/mean/max = 28.18, 61.35, 84.30
# Layer 120, depth_maps.shape = (300, 300, 121)
# Building Layer 121
#  1.078461121749677, 0.05,  1.7212891554872753,  0.3994576363440578
# azi, dip, dipping_plane min/mean/max = 57.4057354731169, 0.05592219159001266, 0.00, 0.29, 0.57
# current_depth_map min/mean/max = 5336.09, 5933.34, 6688.84
# thickness_map min/mean/max = 3.04, 63.06, 101.55
# Layer 121, depth_maps.shape = (300, 300, 122)
# Building Layer 122
#  0.9999999999999999, 0.6054221360529293,  1.438354212266029,  0.19784492096097872
# azi, dip, dipping_plane min/mean/max = 292.66197049696643, 0.04171385213420231, 0.00, 0.20, 0.40
# current_depth_map min/mean/max = 5302.14, 5907.25, 6661.30
# thickness_map min/mean/max = 16.35, 26.09, 38.93
# Layer 122, depth_maps.shape = (300, 300, 123)
# Building Layer 123
#  1.0, 0.46661246781050425,  1.7632353650615324,  0.34324319345731663
# azi, dip, dipping_plane min/mean/max = 35.03689636343906, 0.14683339113437788, 0.00, 0.75, 1.51
# current_depth_map min/mean/max = 5288.22, 5879.94, 6625.02
# thickness_map min/mean/max = 11.69, 27.31, 52.69
# Layer 123, depth_maps.shape = (300, 300, 124)
# Building Layer 124
#  1.0, 0.4272656457057551,  1.5079940253396233,  0.2744140440568747
# azi, dip, dipping_plane min/mean/max = 243.69287479691837, 0.019428656158838487, 0.00, 0.10, 0.19
# current_depth_map min/mean/max = 5236.08, 5835.53, 6586.29
# thickness_map min/mean/max = 19.19, 44.41, 66.32
# Layer 124, depth_maps.shape = (300, 300, 125)
# Building Layer 125
#  1.0, 0.27527567152420573,  1.713894870429069,  0.31970473258114523
# azi, dip, dipping_plane min/mean/max = 297.69483403270664, 0.015211234551361308, 0.00, 0.08, 0.15
# current_depth_map min/mean/max = 5181.94, 5785.83, 6549.03
# thickness_map min/mean/max = 13.77, 49.70, 85.91
# Layer 125, depth_maps.shape = (300, 300, 126)
# Building Layer 126
#  1.0000000000000002, 0.6126244948043765,  1.363190490894068,  0.16371983752424088
# azi, dip, dipping_plane min/mean/max = 1.3301120743484818, 0.010758883022791599, 0.00, 0.04, 0.08
# current_depth_map min/mean/max = 5129.99, 5739.48, 6495.59
# thickness_map min/mean/max = 28.28, 46.35, 63.72
# Layer 126, depth_maps.shape = (300, 300, 127)
# Building Layer 127
#  1.0, 0.5593121268962737,  1.429785862875711,  0.22992630732319955
# azi, dip, dipping_plane min/mean/max = 349.5642104360999, 0.08593744810750081, 0.00, 0.37, 0.74
# current_depth_map min/mean/max = 5100.25, 5695.05, 6459.74
# thickness_map min/mean/max = 23.78, 44.43, 65.62
# Layer 127, depth_maps.shape = (300, 300, 128)
# Building Layer 128
#  1.0, 0.18655617189856055,  1.4970492352924254,  0.3554921749297279
# azi, dip, dipping_plane min/mean/max = 127.70627028171499, 0.08969593069496784, 0.00, 0.46, 0.93
# current_depth_map min/mean/max = 5035.31, 5641.21, 6409.73
# thickness_map min/mean/max = 10.60, 53.84, 80.36
# Layer 128, depth_maps.shape = (300, 300, 129)
# Building Layer 129
#  1.0, 0.4203953163083112,  1.6764130262779622,  0.31740946449252666
# azi, dip, dipping_plane min/mean/max = 159.6437655236968, 0.040944104588256036, 0.00, 0.19, 0.39
# current_depth_map min/mean/max = 4959.12, 5583.47, 6337.15
# thickness_map min/mean/max = 23.77, 57.74, 98.31
# Layer 129, depth_maps.shape = (300, 300, 130)
# Building Layer 130
#  1.0, 0.15416666770435505,  1.6081420377974118,  0.27053893159221426
# azi, dip, dipping_plane min/mean/max = 88.20252941244074, 0.08351055625899162, 0.00, 0.32, 0.64
# current_depth_map min/mean/max = 4942.27, 5531.72, 6289.88
# thickness_map min/mean/max = 8.12, 51.75, 79.34
# Layer 130, depth_maps.shape = (300, 300, 131)
# Building Layer 131
#  1.0939144077495264, 0.05,  1.8221194346802658,  0.41523074290837003
# azi, dip, dipping_plane min/mean/max = 292.82515843946226, 0.05379879376262808, 0.00, 0.26, 0.52
# current_depth_map min/mean/max = 4865.06, 5459.37, 6246.64
# thickness_map min/mean/max = 3.30, 72.35, 118.78
# Layer 131, depth_maps.shape = (300, 300, 132)
# Building Layer 132
#  1.0000000000000002, 0.2017869288455615,  1.677651275021377,  0.4133164951520839
# azi, dip, dipping_plane min/mean/max = 213.46095320661337, 0.13296814784340982, 0.00, 0.68, 1.36
# current_depth_map min/mean/max = 4755.66, 5392.26, 6215.36
# thickness_map min/mean/max = 12.77, 67.10, 116.70
# Layer 132, depth_maps.shape = (300, 300, 133)
# Building Layer 133
#  0.9999999999999999, 0.21973322446236754,  1.919057532261772,  0.4220033037285833
# azi, dip, dipping_plane min/mean/max = 208.11945353176645, 0.03278550462162144, 0.00, 0.16, 0.33
# current_depth_map min/mean/max = 4681.55, 5329.91, 6133.98
# thickness_map min/mean/max = 13.61, 62.36, 116.71
# Layer 133, depth_maps.shape = (300, 300, 134)
# Building Layer 134
#  1.0, 0.5545203608914852,  1.4275720391450215,  0.23666479815807678
# azi, dip, dipping_plane min/mean/max = 226.85312064546724, 0.09604181802915801, 0.00, 0.50, 1.00
# current_depth_map min/mean/max = 4622.43, 5286.62, 6085.90
# thickness_map min/mean/max = 25.86, 43.28, 64.97
# Layer 134, depth_maps.shape = (300, 300, 135)
# Building Layer 135
#  1.0, 0.16770306894314613,  1.9515620065452108,  0.4326974146451806
# azi, dip, dipping_plane min/mean/max = 206.16277381870245, 0.04763428652846968, 0.00, 0.24, 0.47
# current_depth_map min/mean/max = 4601.91, 5236.25, 6009.56
# thickness_map min/mean/max = 8.70, 50.37, 98.01
# Layer 135, depth_maps.shape = (300, 300, 136)
# Building Layer 136
#  1.0, 0.4850712129048913,  1.4134396385010557,  0.20862441560200423
# azi, dip, dipping_plane min/mean/max = 110.55955904155516, 0.028250481016522055, 0.00, 0.13, 0.27
# current_depth_map min/mean/max = 4577.54, 5208.42, 5993.31
# thickness_map min/mean/max = 13.83, 27.83, 38.77
# Layer 136, depth_maps.shape = (300, 300, 137)
# Building Layer 137
#  1.0625988527418548, 0.05,  1.8600959061636215,  0.404463046364542
# azi, dip, dipping_plane min/mean/max = 315.80180098444094, 0.05663650285794031, 0.00, 0.30, 0.59
# current_depth_map min/mean/max = 4542.92, 5165.32, 5972.84
# thickness_map min/mean/max = 2.15, 43.10, 72.84
# Layer 137, depth_maps.shape = (300, 300, 138)
# Building Layer 138
#  1.0, 0.19242577222781565,  1.6042077553414646,  0.356733167160573
# azi, dip, dipping_plane min/mean/max = 162.06721367052253, 0.016257104123726607, 0.00, 0.08, 0.15
# current_depth_map min/mean/max = 4510.55, 5103.36, 5922.63
# thickness_map min/mean/max = 12.04, 61.96, 99.01
# ...
# 	... k: 6, voxel_count: 1980000, sublayer_current_depth_map.mean: 5508.41
# 	... k: 7, voxel_count: 2070000, sublayer_current_depth_map.mean: 5509.41
# 	... k: 8, voxel_count: 2160000, sublayer_current_depth_map.mean: 5510.41
# 	... k: 9, voxel_count: 2250000, sublayer_current_depth_map.mean: 5511.41
# 	... k: 10, voxel_count: 2340000, sublayer_current_depth_map.mean: 5512.41
# 	... k: 11, voxel_count: 2430000, sublayer_current_depth_map.mean: 5513.41
# 	... k: 12, voxel_count: 2520000, sublayer_current_depth_map.mean: 5514.41
# 	... k: 13, voxel_count: 2610000, sublayer_current_depth_map.mean: 5515.41
# 	... k: 14, voxel_count: 2700000, sublayer_current_depth_map.mean: 5516.41
# 	... k: 15, voxel_count: 2790000, sublayer_current_depth_map.mean: 5517.41
# 	... k: -15, voxel_count: 2880000, sublayer_current_depth_map.mean: 7178.42
# 	... k: -14, voxel_count: 2970000, sublayer_current_depth_map.mean: 7179.42
# 	... k: -13, voxel_count: 3060000, sublayer_current_depth_map.mean: 7180.42
# 	... k: -12, voxel_count: 3150000, sublayer_current_depth_map.mean: 7181.42
# 	... k: -11, voxel_count: 3240000, sublayer_current_depth_map.mean: 7182.42
# 	... k: -10, voxel_count: 3330000, sublayer_current_depth_map.mean: 7183.42
# 	... k: -9, voxel_count: 3420000, sublayer_current_depth_map.mean: 7184.42
# 	... k: -8, voxel_count: 3510000, sublayer_current_depth_map.mean: 7185.42
# 	... k: -7, voxel_count: 3600000, sublayer_current_depth_map.mean: 7186.42
# 	... k: -6, voxel_count: 3690000, sublayer_current_depth_map.mean: 7187.42
# 	... k: -5, voxel_count: 3780000, sublayer_current_depth_map.mean: 7188.42
# 	... k: -4, voxel_count: 3870000, sublayer_current_depth_map.mean: 7189.42
# 	... k: -3, voxel_count: 3960000, sublayer_current_depth_map.mean: 7190.42
# 	... k: -2, voxel_count: 4050000, sublayer_current_depth_map.mean: 7191.42
# 	... k: -1, voxel_count: 4140000, sublayer_current_depth_map.mean: 7192.42
# 	... k: 0, voxel_count: 4230000, sublayer_current_depth_map.mean: 7193.42
# 	... k: 1, voxel_count: 4320000, sublayer_current_depth_map.mean: 7194.42
# 	... k: 2, voxel_count: 4410000, sublayer_current_depth_map.mean: 7195.42
# 	... k: 3, voxel_count: 4500000, sublayer_current_depth_map.mean: 7196.42
# 	... k: 4, voxel_count: 4590000, sublayer_current_depth_map.mean: 7197.42
# 	... k: 5, voxel_count: 4680000, sublayer_current_depth_map.mean: 7198.42
# 	... k: 6, voxel_count: 4770000, sublayer_current_depth_map.mean: 7199.42
# 	... k: 7, voxel_count: 4860000, sublayer_current_depth_map.mean: 7200.42
# 	... k: 8, voxel_count: 4950000, sublayer_current_depth_map.mean: 7201.42
# 	... k: 9, voxel_count: 5040000, sublayer_current_depth_map.mean: 7202.42
# 	... k: 10, voxel_count: 5130000, sublayer_current_depth_map.mean: 7203.42
# 	... k: 11, voxel_count: 5220000, sublayer_current_depth_map.mean: 7204.42
# 	... k: 12, voxel_count: 5310000, sublayer_current_depth_map.mean: 7205.42
# 	... k: 13, voxel_count: 5400000, sublayer_current_depth_map.mean: 7206.42
# 	... k: 14, voxel_count: 5490000, sublayer_current_depth_map.mean: 7207.42
# 	... k: 15, voxel_count: 5580000, sublayer_current_depth_map.mean: 7208.42
# 	... k: -15, voxel_count: 5670000, sublayer_current_depth_map.mean: 7186.05
# 	... k: -14, voxel_count: 5760000, sublayer_current_depth_map.mean: 7187.05
# 	... k: -13, voxel_count: 5850000, sublayer_current_depth_map.mean: 7188.05
# 	... k: -12, voxel_count: 5940000, sublayer_current_depth_map.mean: 7189.05
# 	... k: -11, voxel_count: 6030000, sublayer_current_depth_map.mean: 7190.05
# 	... k: -10, voxel_count: 6120000, sublayer_current_depth_map.mean: 7191.05
# 	... k: -9, voxel_count: 6210000, sublayer_current_depth_map.mean: 7192.05
# 	... k: -8, voxel_count: 6300000, sublayer_current_depth_map.mean: 7193.05
# 	... k: -7, voxel_count: 6390000, sublayer_current_depth_map.mean: 7194.05
# 	... k: -6, voxel_count: 6480000, sublayer_current_depth_map.mean: 7195.05
# 	... k: -5, voxel_count: 6570000, sublayer_current_depth_map.mean: 7196.05
# 	... k: -4, voxel_count: 6660000, sublayer_current_depth_map.mean: 7197.05
# 	... k: -3, voxel_count: 6750000, sublayer_current_depth_map.mean: 7198.05
# 	... k: -2, voxel_count: 6840000, sublayer_current_depth_map.mean: 7199.05
# 	... k: -1, voxel_count: 6930000, sublayer_current_depth_map.mean: 7200.05
# 	... k: 0, voxel_count: 7020000, sublayer_current_depth_map.mean: 7201.05
# 	... k: 1, voxel_count: 7110000, sublayer_current_depth_map.mean: 7202.05
# 	... k: 2, voxel_count: 7200000, sublayer_current_depth_map.mean: 7203.05
# 	... k: 3, voxel_count: 7290000, sublayer_current_depth_map.mean: 7204.05
# 	... k: 4, voxel_count: 7380000, sublayer_current_depth_map.mean: 7205.05
# 	... k: 5, voxel_count: 7470000, sublayer_current_depth_map.mean: 7206.05
# 	... k: 6, voxel_count: 7560000, sublayer_current_depth_map.mean: 7207.05
# 	... k: 7, voxel_count: 7650000, sublayer_current_depth_map.mean: 7208.05
# 	... k: 8, voxel_count: 7740000, sublayer_current_depth_map.mean: 7209.05
# 	... k: 9, voxel_count: 7830000, sublayer_current_depth_map.mean: 7210.05
# 	... k: 10, voxel_count: 7920000, sublayer_current_depth_map.mean: 7211.05
# 	... k: 11, voxel_count: 8010000, sublayer_current_depth_map.mean: 7212.05
# 	... k: 12, voxel_count: 8100000, sublayer_current_depth_map.mean: 7213.05
# 	... k: 13, voxel_count: 8190000, sublayer_current_depth_map.mean: 7214.05
# 	... k: 14, voxel_count: 8280000, sublayer_current_depth_map.mean: 7215.05
# 	... k: 15, voxel_count: 8370000, sublayer_current_depth_map.mean: 7216.05
# 	... k: -15, voxel_count: 8460000, sublayer_current_depth_map.mean: 11413.79
# 	... k: -14, voxel_count: 8550000, sublayer_current_depth_map.mean: 11414.79
# 	... k: -13, voxel_count: 8640000, sublayer_current_depth_map.mean: 11415.79
# 	... k: -12, voxel_count: 8730000, sublayer_current_depth_map.mean: 11416.79
# 	... k: -11, voxel_count: 8820000, sublayer_current_depth_map.mean: 11417.79
# 	... k: -10, voxel_count: 8910000, sublayer_current_depth_map.mean: 11418.79
# 	... k: -9, voxel_count: 9000000, sublayer_current_depth_map.mean: 11419.79
# 	... k: -8, voxel_count: 9090000, sublayer_current_depth_map.mean: 11420.79
# 	... k: -7, voxel_count: 9180000, sublayer_current_depth_map.mean: 11421.79
# 	... k: -6, voxel_count: 9270000, sublayer_current_depth_map.mean: 11422.79
# 	... k: -5, voxel_count: 9360000, sublayer_current_depth_map.mean: 11423.79
# 	... k: -4, voxel_count: 9450000, sublayer_current_depth_map.mean: 11424.79
# 	... k: -3, voxel_count: 9540000, sublayer_current_depth_map.mean: 11425.79
# 	... k: -2, voxel_count: 9630000, sublayer_current_depth_map.mean: 11426.79
# 	... k: -1, voxel_count: 9720000, sublayer_current_depth_map.mean: 11427.79
# 	... k: 0, voxel_count: 9810000, sublayer_current_depth_map.mean: 11428.79
# 	... k: 1, voxel_count: 9900000, sublayer_current_depth_map.mean: 11429.79
# 	... k: 2, voxel_count: 9990000, sublayer_current_depth_map.mean: 11430.79
# 	... k: 3, voxel_count: 10080000, sublayer_current_depth_map.mean: 11431.79
# 	... k: 4, voxel_count: 10170000, sublayer_current_depth_map.mean: 11432.79
# 	... k: 5, voxel_count: 10260000, sublayer_current_depth_map.mean: 11433.79
# 	... k: 6, voxel_count: 10350000, sublayer_current_depth_map.mean: 11434.79
# 	... k: 7, voxel_count: 10440000, sublayer_current_depth_map.mean: 11435.79
# 	... k: 8, voxel_count: 10530000, sublayer_current_depth_map.mean: 11436.79
# 	... k: 9, voxel_count: 10620000, sublayer_current_depth_map.mean: 11437.79
# 	... k: 10, voxel_count: 10710000, sublayer_current_depth_map.mean: 11438.79
# 	... k: 11, voxel_count: 10800000, sublayer_current_depth_map.mean: 11439.79
# 	... k: 12, voxel_count: 10890000, sublayer_current_depth_map.mean: 11440.79
# 	... k: 13, voxel_count: 10980000, sublayer_current_depth_map.mean: 11441.79
# 	... k: 14, voxel_count: 11070000, sublayer_current_depth_map.mean: 11442.79
# 	... k: 15, voxel_count: 11160000, sublayer_current_depth_map.mean: 11443.79
# 	... k: -15, voxel_count: 11250000, sublayer_current_depth_map.mean: 12593.41
# 	... k: -14, voxel_count: 11340000, sublayer_current_depth_map.mean: 12593.51
# 	... k: -13, voxel_count: 11430000, sublayer_current_depth_map.mean: 12593.62
# 	... k: -12, voxel_count: 11520000, sublayer_current_depth_map.mean: 12593.72
# 	... k: -11, voxel_count: 11610000, sublayer_current_depth_map.mean: 12593.81
# 	... k: -10, voxel_count: 11700000, sublayer_current_depth_map.mean: 12593.91
# 	... k: -9, voxel_count: 11790000, sublayer_current_depth_map.mean: 12594.01
# 	... k: -8, voxel_count: 11880000, sublayer_current_depth_map.mean: 12594.10
# 	... k: -7, voxel_count: 11970000, sublayer_current_depth_map.mean: 12594.20
# 	... k: -6, voxel_count: 12060000, sublayer_current_depth_map.mean: 12594.29
# 	... k: -5, voxel_count: 12150000, sublayer_current_depth_map.mean: 12594.38
# 	... k: -4, voxel_count: 12240000, sublayer_current_depth_map.mean: 12594.47
# 	... k: -3, voxel_count: 12330000, sublayer_current_depth_map.mean: 12594.56
# 	... k: -2, voxel_count: 12420000, sublayer_current_depth_map.mean: 12594.65
# 	... k: -1, voxel_count: 12510000, sublayer_current_depth_map.mean: 12594.74
# 	... k: 0, voxel_count: 12600000, sublayer_current_depth_map.mean: 12594.83
# 	... k: 1, voxel_count: 12690000, sublayer_current_depth_map.mean: 12594.91
# 	... k: 2, voxel_count: 12780000, sublayer_current_depth_map.mean: 12594.99
# 	... k: 3, voxel_count: 12870000, sublayer_current_depth_map.mean: 12595.08
# 	... k: 4, voxel_count: 12960000, sublayer_current_depth_map.mean: 12595.16
# 	... k: 5, voxel_count: 13050000, sublayer_current_depth_map.mean: 12595.24
# 	... k: 6, voxel_count: 13140000, sublayer_current_depth_map.mean: 12595.32
# 	... k: 7, voxel_count: 13230000, sublayer_current_depth_map.mean: 12595.40
# 	... k: 8, voxel_count: 13320000, sublayer_current_depth_map.mean: 12595.48
# 	... k: 9, voxel_count: 13410000, sublayer_current_depth_map.mean: 12595.55
# 	... k: 10, voxel_count: 13500000, sublayer_current_depth_map.mean: 12595.63
# 	... k: 11, voxel_count: 13590000, sublayer_current_depth_map.mean: 12595.70
# 	... k: 12, voxel_count: 13680000, sublayer_current_depth_map.mean: 12595.77
# 	... k: 13, voxel_count: 13770000, sublayer_current_depth_map.mean: 12595.85
# 	... k: 14, voxel_count: 13860000, sublayer_current_depth_map.mean: 12595.92
# 	... k: 15, voxel_count: 13950000, sublayer_current_depth_map.mean: 12595.99
# 	...onlap_segments min: 0.0, mean: 0.012301587499678135, max: 31.0, % non-zero: 0.007894063492063492
#     ... finished putting onlap surface in onlap_segments ...
#
#
#    ...(pre-faulting) onlap segments created. min: 0.0, mean: 0.01230, max: 31.0, voxel count: 8951868
#
#    ...(pre-faulting) onlap segments created.shape = (300, 300, 12600)
# Applying simple vertical anti-alias filter
#  ... create 4 faults
#  ... 4 faults will be inserted in clustered mode with
#  ... Self branching
#  ... Computing branch number  0
#  ... Recomputing b_ini for better branching
#  ... Recomputing b_ini for better branching
#  ... Recomputing b_ini for better branching
#  ... Recomputing b_ini for better branching
#  ... Branch along axis  x
#      ... Building from left to right
#      ... Computing fault number  1
#      ... Computing fault number  2
#  ... Computing branch number  1
#  ... Recomputing a_ini for better branching
#  ... Recomputing a_ini for better branching
#  ... Recomputing a_ini for better branching
#  ... Recomputing a_ini for better branching
#  ... Branch along axis  y
#      ... Building from right to left
#      ... Computing fault number  3
#
#
#  . starting 'build_faults'.
#    ... self.cfg.verbose = True
#   0%|          | 0/4 [00:00<?, ?it/s]
#  ... inserting fault 0 with throw 6.12
#    ... fault ellipsoid semi-axes (a, b, c): 197.04, 508.15, 5652.75
#    ... fault ellipsoid origin (x, y, z): 230.62, 108.00, -430.21
#    ... tilt_pct: 62.88
#    ...z for bottom of ellipsoid at depth (samples) = -2431863.0
#    ...shape of output_cube = (300, 300, 1260)
#    ...infill_factor, pad_samples = 10, 10
#    ...shear_zone_width (samples) = 1.5
#    ...gouge_pctile (percent*100) = 66.19147194517308
#    .... output_cube.shape = (300, 300, 1260)
#    .... (np.arange(output_cube.shape[2])*infill_factor).shape = (1260,)
#   0%|          | 0/4 [00:11<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mn.build_model(user_json='./config/example.json', run_id=20)
#
# File /raid/ridhwan/synthoseis/main.py:36, in build_model(user_json, run_id, test_mode, rpm_factors)
#      34 f = Faults(p, depth_maps, onlap_list, geo_models, fan_list, fan_thicknesses)
#      35 # Apply faults to depth maps and age volume, and output faulted files
# ---> 36 f.apply_faulting_to_geomodels_and_depth_maps()
#      37 # Build faulted lithology, net_to_gross and depth and randomised models
#      38 f.build_faulted_property_geomodels(facies)
#
# File /raid/ridhwan/synthoseis/datagenerator/Faults.py:143, in Faults.apply_faulting_to_geomodels_and_depth_maps(self)
#     139 # Make a dictionary of zero-thickness onlapping layers before faulting
#     140 onlap_clip_dict = find_zero_thickness_onlapping_layers(
#     141     self.unfaulted_depth_maps, self.onlap_horizon_list
#     142 )
# --> 143 _ = self.generate_faults()
#     145 # Apply faulting to age model, net_to_gross cube & onlap segments
#     146 self.faulted_age_volume[:] = self.apply_xyz_displacement(
#     147     self.vols.geologic_age[:]
#     148 ).astype("float")
#
# File /raid/ridhwan/synthoseis/datagenerator/Faults.py:689, in Faults.generate_faults(self)
#     681 self.cfg.write_to_logfile(
#     682     f"Noise_level: {self.cfg.fnoise}",
#     683     mainkey="model_parameters",
#     684     subkey="noise_level",
#     685     val=self.cfg.fnoise,
#     686 )
#     688 # Build faults, and sum displacements
# --> 689 displacements_classification, hockeys = self.build_faults(fault_params)
#     690 if self.cfg.model_qc_volumes:
#     691     # Write max fault throw cube to disk
#     692     self.vols.write_cube_to_disk(self.max_fault_throw[:], "max_fault_throw")
#
# File /raid/ridhwan/synthoseis/datagenerator/Faults.py:903, in Faults.build_faults(self, fp, verbose)
#     893 fp["shear_zone_width"] = np.zeros(self.cfg.number_faults)
#     894 fp["gouge_pctile"] = np.zeros(self.cfg.number_faults)
#     895 (
#     896     displacement,
#     897     displacement_classification,
#     898     interpolation,
#     899     hockey_stick,
#     900     fault_segm,
#     901     ellipsoid,
#     902     fp,
# --> 903 ) = self.get_displacement_vector(
#     904     semi_axes, origin, throw, tilt, wb, ifault, fp
#     905 )
#     907 if verbose:
#     908     print("     ... hockey_stick = " + str(hockey_stick))
#
# File /raid/ridhwan/synthoseis/datagenerator/Faults.py:1847, in Faults.get_displacement_vector(self, semi_axes, origin, throw, tilt, wb, index, fp)
#    1845 ellipsoid = self.rotate_3d_ellipsoid(x0, y0, z0, a, b, c, tilt)
#    1846 fault_segments = self.get_fault_plane_sobel(ellipsoid)
# -> 1847 z_idx = self.get_fault_centre(ellipsoid, wb, fault_segments, index)
#    1849 # Initialise return objects in case z_idx size == 0
#    1850 interpolation = False
#
# File /raid/ridhwan/synthoseis/datagenerator/Faults.py:2163, in Faults.get_fault_centre(self, ellipsoid, wb_time_map, z_on_ellipse, index)
#    2157         print(
#    2158             "    ... Empty intersection between fault and cube, assign d-max at cube lower corner"
#    2159         )
#    2161     return random_idx
# -> 2163 z_idx = get_middle_z(ellipsoid, wb_time_map, index)
#    2164 return z_idx
#
# File /raid/ridhwan/synthoseis/datagenerator/Faults.py:2145, in Faults.get_fault_centre.<locals>.get_middle_z(ellipse, wb_map, idx, verbose)
#    2142     do_it = False
#    2143     break
# -> 2145 random_idx = xyz_xyz[:, np.random.choice(xyz_xyz.shape[1])]
#    2146 print(
#    2147     "   ... Computing fault middle to hang max displacement function"
#    2148 )
#    2149 print("    ... x idx for max displacement  = ", random_idx[0])
#
# File numpy/random/mtrand.pyx:945, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %% [markdown]
# Let's check to see if the test mode seismic data successfully wrote to a temp location. If the data looks correct, turn off test mode and run the full model. A full model of size `(300,300,1250)` will take 30-60 minutes to complete.

# %%
# %ls /raid/ridhwan/synthoseis/synthoseis_example_test_mode_/seismic__2025.59576289_1/seismicCubes_RFC_fullstack*
# Out:
# /raid/ridhwan/synthoseis/synthoseis_example_test_mode_/seismic__2025.59576289_1/seismicCubes_RFC_fullstack_2025.59576289.npy*

# %%
seismic = np.load('/raid/ridhwan/synthoseis/synthoseis_example_test_mode_/seismic__2025.59576289_1/seismicCubes_RFC_fullstack_2025.59576289.npy')
print(seismic.shape)
# Out:
# (50, 50, 1259)

# %%
plt.figure(figsize=(3,3))
plt.title('Depth Slice: 300')
plt.imshow(seismic[...,300], cmap=plt.cm.seismic)
plt.show()

# %%
import matplotlib.pyplot as plt
inline_index = seismic.shape[0] // 2      # middle inline
crossline_index = seismic.shape[1] // 2   # middle crossline

inline = seismic[inline_index, :, :]      # shape [crossline, depth]
crossline = seismic[:, crossline_index, :] # shape [inline, depth]

# Plot inline
plt.figure(figsize=(12, 6))
plt.imshow(
    inline.T,         # transpose so depth is vertical
    cmap="seismic",   # blue-white-red style
    aspect="auto",    # stretch to fill
    vmin=-0.1, vmax=0.1  # adjust to your amplitude range
)
plt.colorbar(label="Amplitude")
plt.title("Inline Slice")
plt.gca().invert_yaxis()  # depth/time goes down
plt.show()

# Plot crossline
plt.figure(figsize=(12, 6))
plt.imshow(
    crossline.T,
    cmap="seismic",
    aspect="auto",
    vmin=-0.1, vmax=0.1
)
plt.colorbar(label="Amplitude")
plt.title("Crossline Slice")
plt.gca().invert_yaxis()
plt.show()
